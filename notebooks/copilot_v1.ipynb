# %%
from __future__ import annotations

from typing import List, TypedDict

from pydantic import BaseModel, Field
from langchain_mistralai import ChatMistralAI

# %%
class Task(BaseModel):
    id: int
    title: str
    brief: str = Field(..., description="What to cover")

# %%
class Plan(BaseModel):
    blog_title: str
    tasks: List[Task]

# %%
class State(TypedDict):
    topic: str
    plan: Plan

# %%
llm = ChatMistralAI()
# Out:
# ChatMistralAI(output_version=None, profile={}, client=<httpx.Client object at 0x110978790>, async_client=<httpx.AsyncClient object at 0x11095b690>, mistral_api_key=SecretStr('**********'), endpoint='https://api.mistral.ai/v1', model_kwargs={})
